# %%
from src.eda import MovieLensEDA
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.eda import MovieLensEDA
#
# ModuleNotFoundError: No module named 'src'

# %%
if __name__ == "__main__":
    # Ensure you have the data in data/raw/
    eda = MovieLensEDA(data_dir="./data/raw")
    eda.run_all()

# %%
# !pwd
# Out:
# /home/melvin/.local/share/Trash/files/movie-recommender-system/notebooks

# %%
# Définition du chemin cible
 = "/home/melvin/.local/share/Trash/files/movie-recommender-system/figures"
